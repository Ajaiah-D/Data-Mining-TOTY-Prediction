# %%
pip install fuzzywuzzy
# Out:
# Collecting fuzzywuzzy
#   Obtaining dependency information for fuzzywuzzy from https://files.pythonhosted.org/packages/43/ff/74f23998ad2f93b945c0309f825be92e04e0348e062026998b5eefef4c33/fuzzywuzzy-0.18.0-py2.py3-none-any.whl.metadata
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl.metadata (4.9 kB)
# Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry
import time
from bs4 import BeautifulSoup
import pandas as pd
import re
import unicodedata
import matplotlib.pyplot as plt
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %%
comprehensive_df = pd.read_csv('comprehensive_df.csv')

# %%
# Define the URL and headers
url = 'https://fbref.com/en/comps/Big5/defense/players/Big-5-European-Leagues-Stats'
headers = {'User-Agent': 'Mozilla/5.0'}

# Send the GET request
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')

# Select the tbody element that contains all the rows
tbody = soup.select_one('#stats_defense > tbody')

# Initialize a list to store player data
players_data = []

# Check if tbody is found
if tbody:
    # Select all the rows within the tbody
    rows = tbody.select('tr')

        # Iterate through each row and extract the relevant data
    for row in rows:
        player_name_element = row.select_one('td:nth-child(2)')
        tackles_made_element = row.select_one('td:nth-child(11)')
        tackle_percentage_element = row.select_one('td:nth-child(17)')
        interceptions_element = row.select_one('td:nth-child(22)')
        age_element = row.select_one('td:nth-child(7)')
        nation_link = row.select_one('td.left.poptip > a')
    
        # Extract data, leaving fields blank if elements are missing
        player_name = player_name_element.text.strip() if player_name_element else ''
        tackles_made = tackles_made_element.text.strip() if tackles_made_element else ''
        tackle_percentage = tackle_percentage_element.text.strip() if tackle_percentage_element else ''
        interceptions = interceptions_element.text.strip() if interceptions_element else ''
        age = age_element.text.strip() if age_element else ''
         # Extract nationality and remove "Football" part
        nationality = ''
        if nation_link:
            nationality = nation_link['href'].split('/')[-1].replace('-', ' ').title()
            # Remove "Football" and everything after it
            nationality = nationality.split(' Football')[0]
    
        # Append the extracted data to the list
        players_data.append({
            'Player Name': player_name,
            'Tackles Made': tackles_made,
            'Tackle Percentage': tackle_percentage,
            'Interceptions': interceptions,
            'Age': age,
            'Nationality': nationality
        })

    # Convert the list of dictionaries to a DataFrame
    df_players = pd.DataFrame(players_data)

    # Display the DataFrame
    print(df_players)
else:
    print("Table body not found. Please check the selector or page structure.")
# Out:
#             Player Name Tackles Made Tackle Percentage Interceptions Age  \
# 0            Max Aarons           19              58.8             8  23
# 1      Brenden Aaronson           18              50.0             2  22
# 2       Paxten Aaronson            2             100.0             0  19
# 3     Keyliane Abdallah            0                               0  17
# 4      Yunis Abdelhamid           35              57.8            39  35
# ...                 ...          ...               ...           ...  ..
# 2961    Martin Ødegaard           17              29.3            15  24
# 2962        Milan Đurić            0               0.0             1  33
# 2963
# 2964        Milan Đurić            5              50.0             0  33
# 2965   Mateusz Łęgowski           12              42.3             7  20
#
#                  Nationality
# 0                    England
# 1              United States
# 2              United States
# 3                     France
# 4                    Morocco
# ...                      ...
# 2961                  Norway
# 2962  Bosnia And Herzegovina
# 2963
# 2964  Bosnia And Herzegovina
# 2965                  Poland
#
# [2966 rows x 6 columns]

# %%
# Function to normalize a string
def normalize_string(s):
    """
    Normalize a string by removing accents and converting to lowercase.
    """
    # Decompose the unicode string into its base characters and accents
    s = unicodedata.normalize('NFKD', s)
    
    # Encode to ASCII to remove accents, then decode back to string
    s = s.encode('ASCII', 'ignore').decode('ASCII')
    
    # Convert to lowercase
    s = s.lower()
    
    return s

# Apply the normalization function to the 'Player Name' column
df_players['Player Name'] = df_players['Player Name'].apply(normalize_string)

# Display the DataFrame to verify the changes
print(df_players.head())
# Out:
#          Player Name Tackles Made Tackle Percentage Interceptions Age  \
# 0         max aarons           19              58.8             8  23
# 1   brenden aaronson           18              50.0             2  22
# 2    paxten aaronson            2             100.0             0  19
# 3  keyliane abdallah            0                               0  17
# 4   yunis abdelhamid           35              57.8            39  35
#
#      Nationality
# 0        England
# 1  United States
# 2  United States
# 3         France
# 4        Morocco

# %%
len(comprehensive_2023_2024)
# Out:
# 1592

# %%
# Filter comprehensive_df for the 2023/2024 season
comprehensive_2023_2024 = comprehensive_df[comprehensive_df['Season'] == '2023/2024']

# Perform the comparison
matched_players = df_players[df_players['Player Name'].isin(comprehensive_2023_2024['Player'])]

# Display the matched players
print("Matched players in 2023/2024 season:")
print(matched_players)
# Out:
# Matched players in 2023/2024 season:
#             Player Name Tackles Made Tackle Percentage Interceptions Age  \
# 0            max aarons           19              58.8             8  23
# 1      brenden aaronson           18              50.0             2  22
# 2       paxten aaronson            2             100.0             0  19
# 3     keyliane abdallah            0                               0  17
# 4      yunis abdelhamid           35              57.8            39  35
# ...                 ...          ...               ...           ...  ..
# 2956         kurt zouma           17              62.5            29  28
# 2957      igor zubeldia           25              73.1            32  26
# 2958   martin zubimendi           27              54.8            37  24
# 2960     lovro zvonarek            0               0.0             0  18
# 2961     martin degaard           17              29.3            15  24
#
#         Nationality
# 0           England
# 1     United States
# 2     United States
# 3            France
# 4           Morocco
# ...             ...
# 2956         France
# 2957          Spain
# 2958          Spain
# 2960        Croatia
# 2961         Norway
#
# [2442 rows x 6 columns]

# %%
comprehensive_2023_2024.head()
# Out:
#                   Player  Age    Position  Kit Number Nationality  In Squad  \
# 10119   thibaut courtois   31  Goalkeeper           1     Belgium         8
# 10120       andriy lunin   24  Goalkeeper          13     Ukraine        55
# 10121  kepa arrizabalaga   28  Goalkeeper          25       Spain        50
# 10122    lucas canizares   21  Goalkeeper           0       Spain         8
# 10123      mario de luis   21  Goalkeeper           0       Spain         3
#
#        Appearances  Goals  Assists  Yellow Cards  ...  Minutes Played  \
# 10119            5      0        0             0  ...           423.0
# 10120           31      0        0             2  ...          2850.0
# 10121           20      0        0             2  ...          1767.0
# 10122            0      0        0             0  ...             0.0
# 10123            0      0        0             0  ...             0.0
#
#               Club     Season         Team  Placement  League  \
# 10119  Real Madrid  2023/2024  real-madrid          1  laliga
# 10120  Real Madrid  2023/2024  real-madrid          1  laliga
# 10121  Real Madrid  2023/2024  real-madrid          1  laliga
# 10122  Real Madrid  2023/2024  real-madrid          1  laliga
# 10123  Real Madrid  2023/2024  real-madrid          1  laliga
#
#       Champions League Domestic Cup TOTY  TOTY_Nominee
# 10119                1            0    0             0
# 10120                1            0    0             0
# 10121                1            0    0             0
# 10122                1            0    0             0
# 10123                1            0    0             0
#
# [5 rows x 25 columns]

# %%
# Filter the DataFrame for the 2023/2024 season and players with more than 5 appearances
comprehensive_2023_2024 = comprehensive_df[(comprehensive_df['Season'] == '2023/2024') & (comprehensive_df['Appearances'] > 20)]

# Find players who are in comprehensive_2023_2024 but not in df_players
missing_players = comprehensive_2023_2024[comprehensive_2023_2024['Player'].apply(lambda x: x not in df_players['Player Name'].values)]

# Display the missing players along with their other attributes
missing_players
# Out:
#                     Player  Age            Position  Kit Number Nationality  \
# 10131      daniel carvajal   31          Right-Back           2       Spain
# 10134      nacho fernandez   33         Centre-Back           6       Spain
# 10153                  NaN   33      Centre-Forward          14       Spain
# 10218              savinho   19        Right Winger          16      Brazil
# 10220     viktor tsygankov   25        Right Winger           8     Ukraine
# ...                    ...  ...                 ...         ...         ...
# 57943  danley jean jacques   23  Defensive Midfield          27       Haiti
# 57952                  NaN   22      Centre-Forward           0     Georgia
# 57954        cheikh sabaly   24         Left Winger          14     Senegal
# 57969          isaak toure   20         Centre-Back          95      France
# 58039      elbasan rashani   30         Left Winger          18      Kosovo
#
#        In Squad  Appearances  Goals  Assists  Yellow Cards  ...  \
# 10131        47           41      6        5             7  ...
# 10134        51           45      0        1             5  ...
# 10153        52           49     17        3             1  ...
# 10218        42           41     11       10             6  ...
# 10220        34           34      8        7             0  ...
# ...         ...          ...    ...      ...           ...  ...
# 57943        36           36      0        0             4  ...
# 57952        22           22     14        4             2  ...
# 57954        33           31      3        1             5  ...
# 57969        26           24      1        1             6  ...
# 58039        25           25      2        1             4  ...
#
#        Minutes Played              Club     Season              Team  \
# 10131          3351.0       Real Madrid  2023/2024       real-madrid
# 10134          3126.0       Real Madrid  2023/2024       real-madrid
# 10153          2097.0       Real Madrid  2023/2024       real-madrid
# 10218          3253.0         Girona FC  2023/2024         fc-girona
# 10220          2275.0         Girona FC  2023/2024         fc-girona
# ...               ...               ...        ...               ...
# 57943          2841.0           FC Metz  2023/2024           fc-metz
# 57952          1965.0           FC Metz  2023/2024           fc-metz
# 57954          1472.0           FC Metz  2023/2024           fc-metz
# 57969          2052.0        FC Lorient  2023/2024        fc-lorient
# 58039          1241.0  Clermont Foot 63  2023/2024  clermont-foot-63
#
#        Placement   League Champions League Domestic Cup TOTY  TOTY_Nominee
# 10131          1   laliga                1            0    0             0
# 10134          1   laliga                1            0    0             0
# 10153          1   laliga                1            0    0             0
# 10218          3   laliga                0            0    0             0
# 10220          3   laliga                0            0    0             0
# ...          ...      ...              ...          ...  ...           ...
# 57943         16  ligue-1                0            0    0             0
# 57952         16  ligue-1                0            0    0             0
# 57954         16  ligue-1                0            0    0             0
# 57969         17  ligue-1                0            0    0             0
# 58039         18  ligue-1                0            0    0             0
#
# [151 rows x 25 columns]

# %%
# Ensure the 'Player Name' column in df_players is of string type
df_players['Player Name'] = df_players['Player Name'].astype(str)

# Ensure the 'Player' column in missing_players is of string type
missing_players['Player'] = missing_players['Player'].astype(str)

# List to store matched results
matched_players = []

# Iterate over the missing players
for missing_name in missing_players['Player']:
    # Perform fuzzy matching
    best_match = process.extractOne(missing_name, df_players['Player Name'], scorer=fuzz.ratio)
    
    # If a match is found, unpack the result
    if best_match:
        match_name, match_score, match_index = best_match
        
        # Ensure the matched age is converted to an integer (in case it isn't already)
        matched_age = int(df_players.iloc[match_index]['Age'])
        missing_age = int(missing_players[missing_players['Player'] == missing_name]['Age'].values[0])
        
        # Calculate the age difference
        age_difference = abs(missing_age - matched_age)

        # Store the matched information including the age difference
        matched_players.append({
            'Missing Player': missing_name,
            'Matched Player': match_name,
            'Match Score': match_score,
            'Missing Age': missing_age,
            'Matched Age': matched_age,
            'Age Difference': age_difference,
            'Missing Nationality': missing_players[missing_players['Player'] == missing_name]['Nationality'].values[0],
            'Matched Nationality': df_players.iloc[match_index]['Nationality']
        })


# Convert the matched_players list to a DataFrame for easy viewing
matched_players_df = pd.DataFrame(matched_players)
# Out:
# C:\Users\haiaj\AppData\Local\Temp\ipykernel_9468\2458982139.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   missing_players['Player'] = missing_players['Player'].astype(str)

# %%
matched_players_df.dtypes
# Out:
# Missing Player         object
# Matched Player         object
# Match Score             int64
# Missing Age             int64
# Matched Age             int64
# Age Difference          int64
# Missing Nationality    object
# Matched Nationality    object
# dtype: object

# %%
# Display the matched players
matched_players_df.head(50)
# Out:
#            Missing Player          Matched Player  Match Score  Missing Age  \
# 0         daniel carvajal           dani carvajal           93           31
# 1         nacho fernandez          enzo fernandez           83           33
# 2                     nan                   natan           75           33
# 3                 savinho                   savio           83           19
# 4        viktor tsygankov        viktor tsyhankov           94           25
# 5           memphis depay                 memphis           70           29
# 6             dani vivian           daniel vivian           92           23
# 7                     nan                   natan           75           33
# 8                     nan                   natan           75           33
# 9           rodri sanchez          robert sanchez           81           23
# 10            dani parejo           daniel parejo           92           34
# 11              jose gaya          jose luis gaya           78           28
# 12                 pepelu                pep biel           71           24
# 13            javi guerra           javier guerra           92           20
# 14             fran perez         francisco perez           80           20
# 15            kike garcia              kike barja           76           33
# 16           abde rebbach     abderrahman rebbach           77           24
# 17       alejandro catena         alejandro balde           77           28
# 18     jose manuel arnaiz             jose arnaiz           76           28
# 19     jose angel carmona           jovane cabral           65           21
# 20          juan iglesias          borja iglesias           81           24
# 21                    nan                   natan           75           33
# 22        oscar rodriguez  oscar rodriguez arnaiz           81           25
# 23                    nan                   natan           75           33
# 24                    nan                   natan           75           33
# 25            jose copete                  copete           71           23
# 26             javi munoz            javier munoz           91           28
# 27                    nan                   natan           75           33
# 28            isi palazon   isaac palazon camacho           62           28
# 29          conan ledesma        jeremias ledesma           62           30
# 30            lucas pires             lucas digne           73           22
# 31           iza carcelen          isaac carcelen           85           30
# 32         robert navarro         roberto navarro           97           21
# 33                    nan                   natan           75           33
# 34              alex pozo             alex moreno           70           24
# 35                  chumi                  juanmi           55           24
# 36                    nan                   natan           75           33
# 37         adrian embarba            adri embarba           92           31
# 38                    nan                   natan           75           33
# 39                    nan                   natan           75           33
# 40  konstantinos tsimikas         kostas tsimikas           83           27
# 41          emerson royal                 emerson           70           24
# 42   pierre-emile hjbjerg          pierre hjbjerg           82           27
# 43          heung-min son           son heung-min           69           30
# 44       djordje petrovic            ore petrovic           86           23
# 45        mykhaylo mudryk         mykhailo mudryk           93           22
# 46        tino livramento    valentino livramento           86           20
# 47                    nan                   natan           75           33
# 48       lukasz fabianski         ukasz fabianski           97           38
# 49                    nan                   natan           75           33
#
#     Matched Age  Age Difference Missing Nationality Matched Nationality
# 0            31               0               Spain               Spain
# 1            22              11               Spain           Argentina
# 2            22              11               Spain              Brazil
# 3            19               0              Brazil              Brazil
# 4            25               0             Ukraine             Ukraine
# 5            29               0         Netherlands         Netherlands
# 6            24               1               Spain               Spain
# 7            22              11               Spain              Brazil
# 8            22              11               Spain              Brazil
# 9            25               2               Spain               Spain
# 10           34               0               Spain               Spain
# 11           28               0               Spain               Spain
# 12           26               2               Spain               Spain
# 13           20               0               Spain               Spain
# 14           20               0               Spain               Spain
# 15           26               7               Spain               Spain
# 16           24               0             Algeria             Algeria
# 17           19               9               Spain               Spain
# 18           28               0               Spain               Spain
# 19           25               4               Spain          Cape Verde
# 20           30               6               Spain               Spain
# 21           22              11               Spain              Brazil
# 22           25               0               Spain               Spain
# 23           22              11               Spain              Brazil
# 24           22              11               Spain              Brazil
# 25           23               0               Spain               Spain
# 26           28               0               Spain               Spain
# 27           22              11               Spain              Brazil
# 28           28               0               Spain               Spain
# 29           30               0           Argentina           Argentina
# 30           30               8              Brazil              France
# 31           30               0               Spain               Spain
# 32           21               0               Spain               Spain
# 33           22              11               Spain              Brazil
# 34           30               6               Spain               Spain
# 35           30               6               Spain               Spain
# 36           22              11               Spain              Brazil
# 37           31               0               Spain               Spain
# 38           22              11               Spain              Brazil
# 39           22              11               Spain              Brazil
# 40           27               0              Greece              Greece
# 41           24               0              Brazil              Brazil
# 42           27               0             Denmark             Denmark
# 43           31               1        Korea, South      Korea Republic
# 44           23               0              Serbia              Serbia
# 45           22               0             Ukraine             Ukraine
# 46           20               0             England             England
# 47           22              11               Spain              Brazil
# 48           38               0              Poland              Poland
# 49           22              11               Spain              Brazil

# %%
# Create a session
session = requests.Session()

# Define the retry strategy with a longer backoff time
retry = Retry(
    total=5,  # Total number of retries
    backoff_factor=5,  # Exponential backoff factor (5, 10, 20, 40 seconds)
    status_forcelist=[429, 500, 502, 503, 504],  # Retry on these HTTP status codes
    allowed_methods=["HEAD", "GET", "OPTIONS"]  # Retry for these methods
)

# Attach the HTTPAdapter with the retry strategy to the session
adapter = HTTPAdapter(max_retries=retry)
session.mount("http://", adapter)
session.mount("https://", adapter)

base_url = "https://fbref.com/en/comps/Big5/{}/defense/players/{}-Big-5-European-Leagues-Stats"
seasons = [
    "2008-2009", "2009-2010", "2010-2011", "2011-2012", "2012-2013",
    "2013-2014", "2014-2015", "2015-2016", "2016-2017", "2017-2018",
    "2018-2019", "2019-2020", "2020-2021", "2021-2022", "2022-2023",
    "2023-2024"
]

all_players_data = []

for season in seasons:
    if season == "2023-2024":
        url = "https://fbref.com/en/comps/Big5/defense/players/Big-5-European-Leagues-Stats"
    else:
        url = base_url.format(season, season)
    
    # Make the request with retry logic
    try:
        response = session.get(url, headers={'User-Agent': 'Mozilla/5.0'})
        response.raise_for_status()  # Raise an error for bad status codes
        soup = BeautifulSoup(response.content, 'html.parser')
        rows = soup.select("#stats_defense > tbody > tr")
        
        for row in rows:
            player_name_element = row.select_one('td:nth-child(2)')
            tackles_made_element = row.select_one('td:nth-child(11)')
            tackle_percentage_element = row.select_one('td:nth-child(17)')
            interceptions_element = row.select_one('td:nth-child(22)')
            age_element = row.select_one('td:nth-child(7)')
            nationality_element = row.select_one('td.left.poptip > a')
            
            if player_name_element and tackles_made_element and tackle_percentage_element and interceptions_element and age_element and nationality_element:
                player_name = player_name_element.text.strip()
                tackles_made = tackles_made_element.text.strip()
                tackle_percentage = tackle_percentage_element.text.strip()
                interceptions = interceptions_element.text.strip()
                age = age_element.text.strip()
                nationality = nationality_element.text.strip().split(' ')[0]  # Get the part before '-football'
                
                all_players_data.append({
                    'Season': season,
                    'Player Name': player_name,
                    'Tackles Made': tackles_made,
                    'Tackle Percentage': tackle_percentage,
                    'Interceptions': interceptions,
                    'Age': age,
                    'Nationality': nationality
                })
        
        # Introduce a random delay between 5 and 10 seconds to avoid detection
        time.sleep(random.uniform(5, 10))

    except requests.exceptions.RequestException as e:
        print(f"Failed to fetch data for season {season}: {e}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[92], line 67
#      56             all_players_data.append({
#      57                 'Season': season,
#      58                 'Player Name': player_name,
#    (...)
#      63                 'Nationality': nationality
#      64             })
#      66     # Introduce a random delay between 5 and 10 seconds to avoid detection
# ---> 67     time.sleep(random.uniform(5, 10))
#      69 except requests.exceptions.RequestException as e:
#      70     print(f"Failed to fetch data for season {season}: {e}")
#
# NameError: name 'random' is not defined

# %%
all_players_data
# Out:
# [{'Season': '2008-2009',
#   'Player Name': 'Jacques Abardonado',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '30',
#   'Nationality': 'fr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Ignazio Abate',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '21',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Christian Abbiati',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '31',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Pato Abbondanzieri',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '35',
#   'Nationality': 'ar'},
#  {'Season': '2008-2009',
#   'Player Name': 'Elvis Abbruscato',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '27',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Djamel Abdoun',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '22',
#   'Nationality': 'dz'},
#  {'Season': '2008-2009',
#   'Player Name': 'Damià Abella',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '26',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Éric Abidal',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '28',
#   'Nationality': 'fr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Fabrice Abriel',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '29',
#   'Nationality': 'fr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Santiago Acasiete',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '30',
#   'Nationality': 'pe'},
#  {'Season': '2008-2009',
#   'Player Name': 'Pietro Accardi',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '25',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Paolo Acerbis',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '27',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Lautaro Acosta',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '20',
#   'Nationality': 'ar'},
#  {'Season': '2008-2009',
#   'Player Name': 'Robert Acquafresca',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '20',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Adaílton',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '31',
#   'Nationality': 'br'},
#  {'Season': '2008-2009',
#   'Player Name': 'Emmanuel Adebayor',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '24',
#   'Nationality': 'tg'},
#  {'Season': '2008-2009',
#   'Player Name': 'Adeílson',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '22',
#   'Nationality': 'br'},
#  {'Season': '2008-2009',
#   'Player Name': 'Daniel Adejo',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '18',
#   'Nationality': 'ng'},
#  {'Season': '2008-2009',
#   'Player Name': 'Khaled Adénon',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '23',
#   'Nationality': 'bj'},
#  {'Season': '2008-2009',
#   'Player Name': 'Geoffrey Adjet',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '20',
#   'Nationality': 'fr'},
#  {'Season': '2008-2009',
#   'Player Name': 'René Adler',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '23',
#   'Nationality': 'de'},
#  {'Season': '2008-2009',
#   'Player Name': 'Youssef Adnane',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '23',
#   'Nationality': 'fr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Adriano',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '26',
#   'Nationality': 'br'},
#  {'Season': '2008-2009',
#   'Player Name': 'Adriano',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '26',
#   'Nationality': 'br'},
#  {'Season': '2008-2009',
#   'Player Name': 'Adriano',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '23',
#   'Nationality': 'br'},
#  {'Season': '2008-2009',
#   'Player Name': 'Adriano',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '26',
#   'Nationality': 'br'},
#  {'Season': '2008-2009',
#   'Player Name': 'Freddy Adu',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '19',
#   'Nationality': 'us'},
#  {'Season': '2008-2009',
#   'Player Name': 'Godfried Aduobe',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '32',
#   'Nationality': 'gh'},
#  {'Season': '2008-2009',
#   'Player Name': 'Aritz Aduriz',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '27',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Rabiu Afolabi',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '28',
#   'Nationality': 'ng'},
#  {'Season': '2008-2009',
#   'Player Name': 'Gabriel Agbonlahor',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '21',
#   'Nationality': 'eng'},
#  {'Season': '2008-2009',
#   'Player Name': 'Daniel Agger',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '23',
#   'Nationality': 'dk'},
#  {'Season': '2008-2009',
#   'Player Name': 'Alessandro Agostini',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '29',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Sergio Agüero',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '20',
#   'Nationality': 'ar'},
#  {'Season': '2008-2009',
#   'Player Name': 'Marcos Aguirre',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '24',
#   'Nationality': 'ar'},
#  {'Season': '2008-2009',
#   'Player Name': 'Stefan Aigner',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '20',
#   'Nationality': 'de'},
#  {'Season': '2008-2009',
#   'Player Name': 'Yakubu Aiyegbeni',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '25',
#   'Nationality': 'ng'},
#  {'Season': '2008-2009',
#   'Player Name': 'Kanga Akalé',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '27',
#   'Nationality': 'ci'},
#  {'Season': '2008-2009',
#   'Player Name': 'Nassim Akrour',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '34',
#   'Nationality': 'dz'},
#  {'Season': '2008-2009',
#   'Player Name': 'Amadou Alassane',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '25',
#   'Nationality': 'fr'},
#  {'Season': '2008-2009',
#   'Player Name': 'David Albelda',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '30',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Gal Alberman',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '25',
#   'Nationality': 'il'},
#  {'Season': '2008-2009',
#   'Player Name': 'Raúl Albiol',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '22',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Thiago Alcántara',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '17',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Gabriele Aldegani',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '32',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Alex',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '26',
#   'Nationality': 'br'},
#  {'Season': '2008-2009',
#   'Player Name': 'Alexis',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '22',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Jérémie Aliadière',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '25',
#   'Nationality': 'fr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Hassane Alla',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '27',
#   'Nationality': 'ma'},
#  {'Season': '2008-2009',
#   'Player Name': 'Hugo Almeida',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '24',
#   'Nationality': 'pt'},
#  {'Season': '2008-2009',
#   'Player Name': 'Sergio Almirón',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '27',
#   'Nationality': 'ar'},
#  {'Season': '2008-2009',
#   'Player Name': 'Manuel Almunia',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '31',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Alejandro Alonso',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '26',
#   'Nationality': 'ar'},
#  {'Season': '2008-2009',
#   'Player Name': 'Iván Alonso',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '29',
#   'Nationality': 'uy'},
#  {'Season': '2008-2009',
#   'Player Name': 'Xabi Alonso',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '26',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Jérôme Alonzo',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '35',
#   'Nationality': 'fr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Jozy Altidore',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '18',
#   'Nationality': 'us'},
#  {'Season': '2008-2009',
#   'Player Name': 'Halil Altıntop',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '25',
#   'Nationality': 'tr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Hamit Altıntop',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '25',
#   'Nationality': 'tr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Cristian Álvarez',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '22',
#   'Nationality': 'ar'},
#  {'Season': '2008-2009',
#   'Player Name': 'Julio Álvarez',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '27',
#   'Nationality': 've'},
#  {'Season': '2008-2009',
#   'Player Name': 'Pablo Álvarez',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '23',
#   'Nationality': 'uy'},
#  {'Season': '2008-2009',
#   'Player Name': 'Pablo Álvarez',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '24',
#   'Nationality': 'ar'},
#  {'Season': '2008-2009',
#   'Player Name': 'Pablo Álvarez',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '28',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Quique Álvarez',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '33',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Afonso Alves',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '27',
#   'Nationality': 'br'},
#  {'Season': '2008-2009',
#   'Player Name': 'Caio Alves',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '22',
#   'Nationality': 'br'},
#  {'Season': '2008-2009',
#   'Player Name': 'Dani Alves',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '25',
#   'Nationality': 'br'},
#  {'Season': '2008-2009',
#   'Player Name': 'Diego Alves',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '23',
#   'Nationality': 'br'},
#  {'Season': '2008-2009',
#   'Player Name': 'Rodrigo Alvim',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '24',
#   'Nationality': 'br'},
#  {'Season': '2008-2009',
#   'Player Name': 'Morgan Amalfitano',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '23',
#   'Nationality': 'fr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Ioannis Amanatidis',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '26',
#   'Nationality': 'gr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Luis Amaranto Perea',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '29',
#   'Nationality': 'co'},
#  {'Season': '2008-2009',
#   'Player Name': 'Amauri',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '28',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Massimo Ambrosini',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '31',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Marco Amelia',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '26',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Shola Ameobi',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '26',
#   'Nationality': 'ng'},
#  {'Season': '2008-2009',
#   'Player Name': 'Pablo Amo',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '30',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Nicolás Amodio',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '25',
#   'Nationality': 'uy'},
#  {'Season': '2008-2009',
#   'Player Name': 'Fernando Amorebieta',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '23',
#   'Nationality': 've'},
#  {'Season': '2008-2009',
#   'Player Name': 'Christian Amoroso',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '31',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Nicola Amoruso',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '33',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Nicola Amoruso',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '33',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Valerio Anastasi',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '18',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Niklas Andersen',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '19',
#   'Nationality': 'de'},
#  {'Season': '2008-2009',
#   'Player Name': 'Anderson',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '20',
#   'Nationality': 'br'},
#  {'Season': '2008-2009',
#   'Player Name': 'Paulo André',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '24',
#   'Nationality': 'br'},
#  {'Season': '2008-2009',
#   'Player Name': 'Leon Andreasen',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '25',
#   'Nationality': 'dk'},
#  {'Season': '2008-2009',
#   'Player Name': 'Leon Andreasen',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '25',
#   'Nationality': 'dk'},
#  {'Season': '2008-2009',
#   'Player Name': 'Yoann Andreu',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '19',
#   'Nationality': 'fr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Keith Andrews',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '27',
#   'Nationality': 'ie'},
#  {'Season': '2008-2009',
#   'Player Name': 'Nicolas Anelka',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '29',
#   'Nationality': 'fr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Juan Ángel Albín',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '22',
#   'Nationality': 'uy'},
#  {'Season': '2008-2009',
#   'Player Name': 'Miguel Ángel Angulo',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '31',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'José Ángel Crespo',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '21',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'José Ángel',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '18',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Miguel Ángel',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '29',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Miguel Ángel Moyá',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '24',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Miguel Ángel Nieto',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '22',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Ângelo',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '27',
#   'Nationality': 'br'},
#  {'Season': '2008-2009',
#   'Player Name': 'Stanislav Angelov',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '30',
#   'Nationality': 'bg'},
#  {'Season': '2008-2009',
#   'Player Name': 'Victor Anichebe',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '20',
#   'Nationality': 'ng'},
#  {'Season': '2008-2009',
#   'Player Name': 'Kévin Anin',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '22',
#   'Nationality': 'fr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Roda Antar',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '27',
#   'Nationality': 'lb'},
#  {'Season': '2008-2009',
#   'Player Name': 'Mirco Antenucci',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '23',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Álvaro Antón',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '24',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Luca Antonini',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '25',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Francesco Antonioli',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '38',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Vitorino Antunes',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '21',
#   'Nationality': 'pt'},
#  {'Season': '2008-2009',
#   'Player Name': 'Dennis Aogo',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '21',
#   'Nationality': 'de'},
#  {'Season': '2008-2009',
#   'Player Name': 'Dudu Aouate',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '30',
#   'Nationality': 'il'},
#  {'Season': '2008-2009',
#   'Player Name': 'Onyekachi Apam',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '21',
#   'Nationality': 'ng'},
#  {'Season': '2008-2009',
#   'Player Name': 'Apoño',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '24',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Alberto Aquilani',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '24',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Youssef El-Arabi',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '21',
#   'Nationality': 'ma'},
#  {'Season': '2008-2009',
#   'Player Name': 'Carlos Aranda',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '28',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Juan Arango',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '28',
#   'Nationality': 've'},
#  {'Season': '2008-2009',
#   'Player Name': 'Daniel Aranzubia',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '28',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Álvaro Arbeloa',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '25',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Julio Arca',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '27',
#   'Nationality': 'ar'},
#  {'Season': '2008-2009',
#   'Player Name': 'Andrea Ardito',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '31',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Luca Ariatti',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '29',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Lorenzo Ariaudo',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '19',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Sylvain Armand',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '27',
#   'Nationality': 'fr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Armando',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '37',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Emiliano Armenteros',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '22',
#   'Nationality': 'ar'},
#  {'Season': '2008-2009',
#   'Player Name': 'Francesc Arnau',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '33',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Loris Arnaud',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '21',
#   'Nationality': 'fr'},
#  {'Season': '2008-2009',
#   'Player Name': 'John Arne Riise',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '27',
#   'Nationality': 'no'},
#  {'Season': '2008-2009',
#   'Player Name': 'Salvatore Aronica',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '30',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Salvatore Aronica',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '30',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Andrey Arshavin',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '27',
#   'Nationality': 'ru'},
#  {'Season': '2008-2009',
#   'Player Name': 'Mikel Arteta',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '26',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'César Arzo',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '22',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Arzu',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '27',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Gerald Asamoah',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '29',
#   'Nationality': 'de'},
#  {'Season': '2008-2009',
#   'Player Name': 'Kwadwo Asamoah',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '19',
#   'Nationality': 'gh'},
#  {'Season': '2008-2009',
#   'Player Name': 'Sergio Asenjo',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '19',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Ian Ashbee',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '31',
#   'Nationality': 'eng'},
#  {'Season': '2008-2009',
#   'Player Name': 'Dean Ashton',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '24',
#   'Nationality': 'eng'},
#  {'Season': '2008-2009',
#   'Player Name': 'Benoît Assou-Ekotto',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '24',
#   'Nationality': 'cm'},
#  {'Season': '2008-2009',
#   'Player Name': 'Paulo Assunção',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '28',
#   'Nationality': 'br'},
#  {'Season': '2008-2009',
#   'Player Name': 'Davide Astori',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '21',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Çağdaş Atan',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '28',
#   'Nationality': 'tr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Timothée Atouba',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '26',
#   'Nationality': 'cm'},
#  {'Season': '2008-2009',
#   'Player Name': 'Lucien Aubey',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '24',
#   'Nationality': 'cg'},
#  {'Season': '2008-2009',
#   'Player Name': 'Fabien Audard',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '30',
#   'Nationality': 'fr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Johan Audel',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '24',
#   'Nationality': 'mq'},
#  {'Season': '2008-2009',
#   'Player Name': 'Renato Augusto',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '20',
#   'Nationality': 'br'},
#  {'Season': '2008-2009',
#   'Player Name': 'Fábio Aurélio',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '28',
#   'Nationality': 'br'},
#  {'Season': '2008-2009',
#   'Player Name': 'Mehmet Aurélio',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '30',
#   'Nationality': 'tr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Gerard Autet',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '29',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'André Ayew',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '18',
#   'Nationality': 'gh'},
#  {'Season': '2008-2009',
#   'Player Name': 'Mimoun Azaouagh',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '25',
#   'Nationality': 'de'},
#  {'Season': '2008-2009',
#   'Player Name': 'César Azpilicueta',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '18',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Abasse Ba',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '32',
#   'Nationality': 'sn'},
#  {'Season': '2008-2009',
#   'Player Name': 'Demba Ba',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '23',
#   'Nationality': 'sn'},
#  {'Season': '2008-2009',
#   'Player Name': 'Issa Ba',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '26',
#   'Nationality': 'sn'},
#  {'Season': '2008-2009',
#   'Player Name': 'Ludovic Baal',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '22',
#   'Nationality': 'gf'},
#  {'Season': '2008-2009',
#   'Player Name': 'Ryan Babel',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '21',
#   'Nationality': 'nl'},
#  {'Season': '2008-2009',
#   'Player Name': 'Marko Babić',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '27',
#   'Nationality': 'hr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Marko Babić',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '27',
#   'Nationality': 'hr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Stefan Babović',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '21',
#   'Nationality': 'rs'},
#  {'Season': '2008-2009',
#   'Player Name': 'Maxime Baca',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '25',
#   'Nationality': 'fr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Mamadou Bagayoko',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '29',
#   'Nationality': 'ml'},
#  {'Season': '2008-2009',
#   'Player Name': 'Nabil Baha',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '26',
#   'Nationality': 'ma'},
#  {'Season': '2008-2009',
#   'Player Name': 'Brahim El Bahri',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '22',
#   'Nationality': 'ma'},
#  {'Season': '2008-2009',
#   'Player Name': 'Logan Bailly',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '22',
#   'Nationality': 'be'},
#  {'Season': '2008-2009',
#   'Player Name': 'Leighton Baines',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '23',
#   'Nationality': 'eng'},
#  {'Season': '2008-2009',
#   'Player Name': 'Davide Baiocco',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '33',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Chris Baird',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '26',
#   'Nationality': 'nir'},
#  {'Season': '2008-2009',
#   'Player Name': 'Zlatan Bajramović',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '28',
#   'Nationality': 'ba'},
#  {'Season': '2008-2009',
#   'Player Name': 'Djamel Bakar',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '19',
#   'Nationality': 'km'},
#  {'Season': '2008-2009',
#   'Player Name': 'Gareth Bale',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '19',
#   'Nationality': 'wls'},
#  {'Season': '2008-2009',
#   'Player Name': 'Mikel Balenziaga',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '20',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Hanno Balitsch',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '27',
#   'Nationality': 'de'},
#  {'Season': '2008-2009',
#   'Player Name': 'Michael Ball',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '28',
#   'Nationality': 'eng'},
#  {'Season': '2008-2009',
#   'Player Name': 'Michael Ballack',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '31',
#   'Nationality': 'de'},
#  {'Season': '2008-2009',
#   'Player Name': 'Salva Ballesta',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '33',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Florent Balmont',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '28',
#   'Nationality': 'fr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Leon Balogun',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '20',
#   'Nationality': 'ng'},
#  {'Season': '2008-2009',
#   'Player Name': 'Mario Balotelli',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '17',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Federico Balzaretti',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '26',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Habib Bamogo',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '26',
#   'Nationality': 'bf'},
#  {'Season': '2008-2009',
#   'Player Name': 'Éver Banega',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '20',
#   'Nationality': 'ar'},
#  {'Season': '2008-2009',
#   'Player Name': 'Karba Bangoura',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '22',
#   'Nationality': 'gn'},
#  {'Season': '2008-2009',
#   'Player Name': 'Albert Baning',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '23',
#   'Nationality': 'cm'},
#  {'Season': '2008-2009',
#   'Player Name': 'Júlio Baptista',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '26',
#   'Nationality': 'br'},
#  {'Season': '2008-2009',
#   'Player Name': 'Javier Baraja',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '27',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Rubén Baraja',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '33',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Rafael Barber',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '27',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Phil Bardsley',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '23',
#   'Nationality': 'sct'},
#  {'Season': '2008-2009',
#   'Player Name': 'Antonino Barillà',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '20',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'José Barkero',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '29',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Nick Barmby',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '34',
#   'Nationality': 'eng'},
#  {'Season': '2008-2009',
#   'Player Name': 'Leon Barnett',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '22',
#   'Nationality': 'eng'},
#  {'Season': '2008-2009',
#   'Player Name': 'Tranquillo Barnetta',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '23',
#   'Nationality': 'ch'},
#  {'Season': '2008-2009',
#   'Player Name': 'Simone Barone',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '30',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'David Barral',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '25',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Édgar Barreto',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '24',
#   'Nationality': 'py'},
#  {'Season': '2008-2009',
#   'Player Name': 'Gareth Barry',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '27',
#   'Nationality': 'eng'},
#  {'Season': '2008-2009',
#   'Player Name': 'Joey Barton',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '25',
#   'Nationality': 'eng'},
#  {'Season': '2008-2009',
#   'Player Name': 'Ahmed Barusso',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '23',
#   'Nationality': 'gh'},
#  {'Season': '2008-2009',
#   'Player Name': 'Andrea Barzagli',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '27',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Pablo Barzola',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '24',
#   'Nationality': 'ar'},
#  {'Season': '2008-2009',
#   'Player Name': 'Cédric Baseya',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '20',
#   'Nationality': 'cd'},
#  {'Season': '2008-2009',
#   'Player Name': 'Chris Basham',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '20',
#   'Nationality': 'eng'},
#  {'Season': '2008-2009',
#   'Player Name': 'Angelos Basinas',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '32',
#   'Nationality': 'gr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Josias Basso',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '19',
#   'Nationality': 'br'},
#  {'Season': '2008-2009',
#   'Player Name': 'Sébastien Bassong',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '22',
#   'Nationality': 'cm'},
#  {'Season': '2008-2009',
#   'Player Name': 'Dušan Basta',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '23',
#   'Nationality': 'rs'},
#  {'Season': '2008-2009',
#   'Player Name': 'Michel Bastos',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '24',
#   'Nationality': 'br'},
#  {'Season': '2008-2009',
#   'Player Name': 'Yıldıray Baştürk',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '29',
#   'Nationality': 'tr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Matthew Bates',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '21',
#   'Nationality': 'eng'},
#  {'Season': '2008-2009',
#   'Player Name': 'Laurent Batlles',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '32',
#   'Nationality': 'fr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Frank Baumann',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '32',
#   'Nationality': 'de'},
#  {'Season': '2008-2009',
#   'Player Name': 'Alexander Baumjohann',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '21',
#   'Nationality': 'de'},
#  {'Season': '2008-2009',
#   'Player Name': 'Jose Baxter',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '16',
#   'Nationality': 'eng'},
#  {'Season': '2008-2009',
#   'Player Name': 'Moustapha Bayal Sall',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '22',
#   'Nationality': 'sn'},
#  {'Season': '2008-2009',
#   'Player Name': 'Iñaki Bea Jauregi',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '30',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Craig Beattie',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '24',
#   'Nationality': 'sct'},
#  {'Season': '2008-2009',
#   'Player Name': 'James Beattie',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '30',
#   'Nationality': 'eng'},
#  {'Season': '2008-2009',
#   'Player Name': 'Andreas Beck',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '21',
#   'Nationality': 'de'},
#  {'Season': '2008-2009',
#   'Player Name': 'David Beckham',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '33',
#   'Nationality': 'eng'},
#  {'Season': '2008-2009',
#   'Player Name': 'Edu Bedia',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '19',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Roman Bednář',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '25',
#   'Nationality': 'cz'},
#  {'Season': '2008-2009',
#   'Player Name': 'Asmir Begović',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '21',
#   'Nationality': 'ba'},
#  {'Season': '2008-2009',
#   'Player Name': 'Valon Behrami',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '23',
#   'Nationality': 'ch'},
#  {'Season': '2008-2009',
#   'Player Name': 'Christian Bekamenga',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '22',
#   'Nationality': 'cm'},
#  {'Season': '2008-2009',
#   'Player Name': 'Emanuele Belardi',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '30',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'David Belenguer',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '35',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Nadir Belhadj',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '26',
#   'Nationality': 'dz'},
#  {'Season': '2008-2009',
#   'Player Name': 'Habib Bellaïd',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '22',
#   'Nationality': 'dz'},
#  {'Season': '2008-2009',
#   'Player Name': 'Craig Bellamy',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '29',
#   'Nationality': 'wls'},
#  {'Season': '2008-2009',
#   'Player Name': 'Craig Bellamy',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '29',
#   'Nationality': 'wls'},
#  {'Season': '2008-2009',
#   'Player Name': 'Manuel Belleri',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '30',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Manuel Belleri',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '30',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Juliano Belletti',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '32',
#   'Nationality': 'br'},
#  {'Season': '2008-2009',
#   'Player Name': 'Gianpaolo Bellini',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '28',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'David Bellion',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '25',
#   'Nationality': 'fr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Claudio Bellucci',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '33',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Carlos Bellvís',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '23',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Djamel Belmadi',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '32',
#   'Nationality': 'dz'},
#  {'Season': '2008-2009',
#   'Player Name': 'Nicola Belmonte',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '21',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Hatem Ben Arfa',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '21',
#   'Nationality': 'fr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Saber Ben Frej',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '29',
#   'Nationality': 'tn'},
#  {'Season': '2008-2009',
#   'Player Name': 'Tal Ben Haim',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '26',
#   'Nationality': 'il'},
#  {'Season': '2008-2009',
#   'Player Name': 'Tal Ben Haim',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '26',
#   'Nationality': 'il'},
#  {'Season': '2008-2009',
#   'Player Name': 'Fahid Ben Khalfallah',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '25',
#   'Nationality': 'tn'},
#  {'Season': '2008-2009',
#   'Player Name': 'Chaouki Ben Saada',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '24',
#   'Nationality': 'tn'},
#  {'Season': '2008-2009',
#   'Player Name': 'Änis Ben-Hatira',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '20',
#   'Nationality': 'tn'},
#  {'Season': '2008-2009',
#   'Player Name': 'Diego Benaglio',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '24',
#   'Nationality': 'ch'},
#  {'Season': '2008-2009',
#   'Player Name': 'Yohan Benalouane',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '21',
#   'Nationality': 'tn'},
#  {'Season': '2008-2009',
#   'Player Name': 'Yossi Benayoun',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '28',
#   'Nationality': 'il'},
#  {'Season': '2008-2009',
#   'Player Name': 'Nicklas Bendtner',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '20',
#   'Nationality': 'dk'},
#  {'Season': '2008-2009',
#   'Player Name': 'Collin Benjamin',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '29',
#   'Nationality': 'na'},
#  {'Season': '2008-2009',
#   'Player Name': 'Benjani',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '29',
#   'Nationality': 'zw'},
#  {'Season': '2008-2009',
#   'Player Name': 'Joe Bennett',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '18',
#   'Nationality': 'eng'},
#  {'Season': '2008-2009',
#   'Player Name': 'Darren Bent',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '24',
#   'Nationality': 'eng'},
#  {'Season': '2008-2009',
#   'Player Name': 'Simone Bentivoglio',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '23',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'David Bentley',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '23',
#   'Nationality': 'eng'},
#  {'Season': '2008-2009',
#   'Player Name': 'Francesco Benussi',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '26',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Karim Benzema',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '20',
#   'Nationality': 'fr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Grégory Béranger',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '26',
#   'Nationality': 'fr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Dimitar Berbatov',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '27',
#   'Nationality': 'bg'},
#  {'Season': '2008-2009',
#   'Player Name': 'Dimitar Berbatov',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '27',
#   'Nationality': 'bg'},
#  {'Season': '2008-2009',
#   'Player Name': 'Pascal Berenguer',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '27',
#   'Nationality': 'fr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Vinícius Bergantin',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '28',
#   'Nationality': 'br'},
#  {'Season': '2008-2009',
#   'Player Name': 'Steve von Bergen',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '25',
#   'Nationality': 'ch'},
#  {'Season': '2008-2009',
#   'Player Name': 'Bryan Bergougnoux',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '25',
#   'Nationality': 'fr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Franck Béria',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '25',
#   'Nationality': 'fr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Marco Bernacci',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '24',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Jesús Berrocal',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '20',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Mathieu Berson',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '28',
#   'Nationality': 'fr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Jérémy Berthod',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '24',
#   'Nationality': 'fr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Beto',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '32',
#   'Nationality': 'pt'},
#  {'Season': '2008-2009',
#   'Player Name': 'Habib Beye',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '30',
#   'Nationality': 'sn'},
#  {'Season': '2008-2009',
#   'Player Name': 'Yacine Bezzaz',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '27',
#   'Nationality': 'dz'},
#  {'Season': '2008-2009',
#   'Player Name': 'Marco Biagianti',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '24',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Frédéric Biancalani',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '34',
#   'Nationality': 'fr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Rolando Bianchi',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '25',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Paolo Bianco',
#   'Tackles Made': '',
# ...
#   'Interceptions': '',
#   'Age': '18',
#   'Nationality': 'de'},
#  {'Season': '2008-2009',
#   'Player Name': 'Nils Fischer',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '21',
#   'Nationality': 'de'},
#  {'Season': '2008-2009',
#   'Player Name': 'Maxence Flachez',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '35',
#   'Nationality': 'fr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Mathieu Flamini',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '24',
#   'Nationality': 'fr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Javier Flaño',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '23',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Miguel Flaño',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '23',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Darren Fletcher',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '24',
#   'Nationality': 'sct'},
#  {'Season': '2008-2009',
#   'Player Name': 'Sergio Floccari',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '26',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Nicolas Florentin',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '30',
#   'Nationality': 'fr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Chico Flores',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '21',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Antonio Floro Flores',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '25',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Mohamed Fofana',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '23',
#   'Nationality': 'ml'},
#  {'Season': '2008-2009',
#   'Player Name': 'Pasquale Foggia',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '25',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Caleb Folan',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '25',
#   'Nationality': 'ie'},
#  {'Season': '2008-2009',
#   'Player Name': 'Héctor Font',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '24',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Jean-Pascal Fontaine',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '19',
#   'Nationality': 'fr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Alberto Fontana',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '41',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Fernando Forestieri',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '18',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Diego Forlán',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '29',
#   'Nationality': 'uy'},
#  {'Season': '2008-2009',
#   'Player Name': 'Bruno Fornaroli',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '20',
#   'Nationality': 'au'},
#  {'Season': '2008-2009',
#   'Player Name': 'Mikael Forssell',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '27',
#   'Nationality': 'fi'},
#  {'Season': '2008-2009',
#   'Player Name': 'Marc-Antoine Fortuné',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '27',
#   'Nationality': 'fr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Marc-Antoine Fortuné',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '27',
#   'Nationality': 'fr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Ben Foster',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '25',
#   'Nationality': 'eng'},
#  {'Season': '2008-2009',
#   'Player Name': 'Robbie Fowler',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '33',
#   'Nationality': 'eng'},
#  {'Season': '2008-2009',
#   'Player Name': 'Ryan France',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '27',
#   'Nationality': 'eng'},
#  {'Season': '2008-2009',
#   'Player Name': 'Daniele Franceschini',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '32',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Ivan Franceschini',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '31',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Guillermo Franco',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '31',
#   'Nationality': 'mx'},
#  {'Season': '2008-2009',
#   'Player Name': 'Leo Franco',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '31',
#   'Nationality': 'ar'},
#  {'Season': '2008-2009',
#   'Player Name': 'Jonathan Franks',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '18',
#   'Nationality': 'eng'},
#  {'Season': '2008-2009',
#   'Player Name': 'Peter Franquart',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '23',
#   'Nationality': 'fr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Peter Franquart',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '23',
#   'Nationality': 'fr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Maik Franz',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '26',
#   'Nationality': 'de'},
#  {'Season': '2008-2009',
#   'Player Name': 'Pierre-Alain Frau',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '28',
#   'Nationality': 'fr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Fred',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '24',
#   'Nationality': 'br'},
#  {'Season': '2008-2009',
#   'Player Name': 'Alexander Frei',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '29',
#   'Nationality': 'ch'},
#  {'Season': '2008-2009',
#   'Player Name': 'Paul Freier',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '29',
#   'Nationality': 'de'},
#  {'Season': '2008-2009',
#   'Player Name': 'Sebastian Freis',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '23',
#   'Nationality': 'de'},
#  {'Season': '2008-2009',
#   'Player Name': 'David de Freitas',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '28',
#   'Nationality': 'fr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Nicolas Frey',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '24',
#   'Nationality': 'fr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Sébastien Frey',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '28',
#   'Nationality': 'fr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Mario Frick',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '33',
#   'Nationality': 'li'},
#  {'Season': '2008-2009',
#   'Player Name': 'Brad Friedel',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '37',
#   'Nationality': 'us'},
#  {'Season': '2008-2009',
#   'Player Name': 'Arne Friedrich',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '29',
#   'Nationality': 'de'},
#  {'Season': '2008-2009',
#   'Player Name': 'Manuel Friedrich',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '28',
#   'Nationality': 'de'},
#  {'Season': '2008-2009',
#   'Player Name': 'Rob Friend',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '27',
#   'Nationality': 'ca'},
#  {'Season': '2008-2009',
#   'Player Name': 'Torsten Frings',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '31',
#   'Nationality': 'de'},
#  {'Season': '2008-2009',
#   'Player Name': 'Clemens Fritz',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '27',
#   'Nationality': 'de'},
#  {'Season': '2008-2009',
#   'Player Name': 'Florian Fromlowitz',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '22',
#   'Nationality': 'de'},
#  {'Season': '2008-2009',
#   'Player Name': 'Christian Fuchs',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '22',
#   'Nationality': 'at'},
#  {'Season': '2008-2009',
#   'Player Name': 'Danny Fuchs',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '32',
#   'Nationality': 'de'},
#  {'Season': '2008-2009',
#   'Player Name': 'Javi Fuego',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '24',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Fabricio Fuentes',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '31',
#   'Nationality': 'ar'},
#  {'Season': '2008-2009',
#   'Player Name': 'Ricardo Fuller',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '28',
#   'Nationality': 'jm'},
#  {'Season': '2008-2009',
#   'Player Name': 'Márton Fülöp',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '25',
#   'Nationality': 'hu'},
#  {'Season': '2008-2009',
#   'Player Name': 'Igor Gabilondo',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '29',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Ismaël Gace',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '21',
#   'Nationality': 'fr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Fernando Gago',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '22',
#   'Nationality': 'ar'},
#  {'Season': '2008-2009',
#   'Player Name': 'Serge Gakpé',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '21',
#   'Nationality': 'tg'},
#  {'Season': '2008-2009',
#   'Player Name': 'Tomáš Galásek',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '35',
#   'Nationality': 'cz'},
#  {'Season': '2008-2009',
#   'Player Name': 'Aarón Galindo',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '26',
#   'Nationality': 'mx'},
#  {'Season': '2008-2009',
#   'Player Name': 'William Gallas',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '30',
#   'Nationality': 'fr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Daniele Galloppa',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '23',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Alessandro Gamberini',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '26',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Kévin Gameiro',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '21',
#   'Nationality': 'fr'},
#  {'Season': '2008-2009',
#   'Player Name': 'Jesús Gámez',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '23',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Morten Gamst Pedersen',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '26',
#   'Nationality': 'no'},
#  {'Season': '2008-2009',
#   'Player Name': 'Christopher Gäng',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '20',
#   'Nationality': 'de'},
#  {'Season': '2008-2009',
#   'Player Name': 'Ezequiel Garay',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '21',
#   'Nationality': 'ar'},
#  {'Season': '2008-2009',
#   'Player Name': 'José García Calvo',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '33',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Carlos García',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '24',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'David García',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '27',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Javi García',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '21',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Jorge García',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '24',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Luis García',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '27',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Luis García',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '30',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Mario García Pizarraya',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '22',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Raúl García',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '22',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Richard Garcia',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '26',
#   'Nationality': 'au'},
#  {'Season': '2008-2009',
#   'Player Name': 'Sergio García',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '25',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Anthony Gardner',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '27',
#   'Nationality': 'eng'},
#  {'Season': '2008-2009',
#   'Player Name': 'Craig Gardner',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '21',
#   'Nationality': 'eng'},
#  {'Season': '2008-2009',
#   'Player Name': 'Ricardo Gardner',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '29',
#   'Nationality': 'jm'},
#  {'Season': '2008-2009',
#   'Player Name': 'Walter Gargano',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '24',
#   'Nationality': 'uy'},
#  {'Season': '2008-2009',
#   'Player Name': 'György Garics',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '24',
#   'Nationality': 'at'},
#  {'Season': '2008-2009',
#   'Player Name': 'Joseba Garmendia',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '22',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Javier Garrido',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '23',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Andrea Gasbarroni',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '26',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Andrea Gasbarroni',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '26',
#   'Nationality': 'it'},
#  {'Season': '2008-2009',
#   'Player Name': 'Edu Gaspar',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '30',
#   'Nationality': 'br'},
#  {'Season': '2008-2009',
#   'Player Name': 'Manolo Gaspar',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '27',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Mario Gaspar',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '17',
#   'Nationality': 'es'},
#  {'Season': '2008-2009',
#   'Player Name': 'Lamine Gassama',
#   'Tackles Made': '',
#   'Tackle Percentage': '',
#   'Interceptions': '',
#   'Age': '18',
#   'Nationality': 'sn'},
#  ...]
