# %%
pip install fuzzywuzzy
# Out:
# Collecting fuzzywuzzy
#   Obtaining dependency information for fuzzywuzzy from https://files.pythonhosted.org/packages/43/ff/74f23998ad2f93b945c0309f825be92e04e0348e062026998b5eefef4c33/fuzzywuzzy-0.18.0-py2.py3-none-any.whl.metadata
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl.metadata (4.9 kB)
# Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry
import time
from bs4 import BeautifulSoup
import pandas as pd
import re
import unicodedata
import matplotlib.pyplot as plt
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import random
# Out:
# C:\Users\haiaj\anaconda3\Lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
comprehensive_df = pd.read_csv('comprehensive_df.csv')
comprehensive_df['Appearances'] = pd.to_numeric(comprehensive_df['Appearances'])
comprehensive_df['Season'] = comprehensive_df['Season'].astype(str)

# %%
# Define the URL and headers
url = 'https://fbref.com/en/comps/Big5/defense/players/Big-5-European-Leagues-Stats'
headers = {'User-Agent': 'Mozilla/5.0'}

# Send the GET request
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')

# Select the tbody element that contains all the rows
tbody = soup.select_one('#stats_defense > tbody')

# Initialize a list to store player data
players_data = []

# Check if tbody is found
if tbody:
    # Select all the rows within the tbody
    rows = tbody.select('tr')

        # Iterate through each row and extract the relevant data
    for row in rows:
        player_name_element = row.select_one('td:nth-child(2)')
        tackles_made_element = row.select_one('td:nth-child(11)')
        tackle_percentage_element = row.select_one('td:nth-child(17)')
        interceptions_element = row.select_one('td:nth-child(22)')
        age_element = row.select_one('td:nth-child(7)')
        nation_link = row.select_one('td.left.poptip > a')
    
        # Extract data, leaving fields blank if elements are missing
        player_name = player_name_element.text.strip() if player_name_element else ''
        tackles_made = tackles_made_element.text.strip() if tackles_made_element else ''
        tackle_percentage = tackle_percentage_element.text.strip() if tackle_percentage_element else ''
        interceptions = interceptions_element.text.strip() if interceptions_element else ''
        age = age_element.text.strip() if age_element else ''
         # Extract nationality and remove "Football" part
        nationality = ''
        if nation_link:
            nationality = nation_link['href'].split('/')[-1].replace('-', ' ').title()
            # Remove "Football" and everything after it
            nationality = nationality.split(' Football')[0]
    
        # Append the extracted data to the list
        players_data.append({
            'Player Name': player_name,
            'Tackles Made': tackles_made,
            'Tackle Percentage': tackle_percentage,
            'Interceptions': interceptions,
            'Age': age,
            'Nationality': nationality
        })

    # Convert the list of dictionaries to a DataFrame
    df_players = pd.DataFrame(players_data)

    # Display the DataFrame
    print(df_players)
else:
    print("Table body not found. Please check the selector or page structure.")
# Out:
#             Player Name Tackles Made Tackle Percentage Interceptions Age  \
# 0            Max Aarons           19              58.8             8  23
# 1      Brenden Aaronson           18              50.0             2  22
# 2       Paxten Aaronson            2             100.0             0  19
# 3     Keyliane Abdallah            0                               0  17
# 4      Yunis Abdelhamid           35              57.8            39  35
# ...                 ...          ...               ...           ...  ..
# 2961    Martin Ødegaard           17              29.3            15  24
# 2962        Milan Đurić            0               0.0             1  33
# 2963
# 2964        Milan Đurić            5              50.0             0  33
# 2965   Mateusz Łęgowski           12              42.3             7  20
#
#                  Nationality
# 0                    England
# 1              United States
# 2              United States
# 3                     France
# 4                    Morocco
# ...                      ...
# 2961                  Norway
# 2962  Bosnia And Herzegovina
# 2963
# 2964  Bosnia And Herzegovina
# 2965                  Poland
#
# [2966 rows x 6 columns]

# %%
# Function to normalize a string
def normalize_string(s):
    """
    Normalize a string by removing accents and converting to lowercase.
    """
    # Decompose the unicode string into its base characters and accents
    s = unicodedata.normalize('NFKD', s)
    
    # Encode to ASCII to remove accents, then decode back to string
    s = s.encode('ASCII', 'ignore').decode('ASCII')
    
    # Convert to lowercase
    s = s.lower()
    
    return s

# Apply the normalization function to the 'Player Name' column
df_players['Player Name'] = df_players['Player Name'].apply(normalize_string)

# Display the DataFrame to verify the changes
print(df_players.head())
# Out:
#          Player Name Tackles Made Tackle Percentage Interceptions Age  \
# 0         max aarons           19              58.8             8  23
# 1   brenden aaronson           18              50.0             2  22
# 2    paxten aaronson            2             100.0             0  19
# 3  keyliane abdallah            0                               0  17
# 4   yunis abdelhamid           35              57.8            39  35
#
#      Nationality
# 0        England
# 1  United States
# 2  United States
# 3         France
# 4        Morocco

# %%
# Filter comprehensive_df for the 2023/2024 season
comprehensive_copy = comprehensive_df[(comprehensive_df['Appearances'] > 15)]

# Perform the comparison
matched_players = df_players[df_players['Player Name'].isin(comprehensive_copy['Player'])]

# Display the matched players
print("Matched players in 2023/2024 season:")
print(matched_players)
# Out:
# Matched players in 2023/2024 season:
#             Player Name Tackles Made Tackle Percentage Interceptions Age  \
# 0            max aarons           19              58.8             8  23
# 1      brenden aaronson           18              50.0             2  22
# 4      yunis abdelhamid           35              57.8            39  35
# 5     salis abdul samed           14              44.4            12  23
# 7       laurent abergel           52              39.6            61  30
# ...                 ...          ...               ...           ...  ..
# 2955       nadir zortea            4              25.0             1  24
# 2956         kurt zouma           17              62.5            29  28
# 2957      igor zubeldia           25              73.1            32  26
# 2958   martin zubimendi           27              54.8            37  24
# 2961     martin degaard           17              29.3            15  24
#
#         Nationality
# 0           England
# 1     United States
# 4           Morocco
# 5             Ghana
# 7            France
# ...             ...
# 2955          Italy
# 2956         France
# 2957          Spain
# 2958          Spain
# 2961         Norway
#
# [2090 rows x 6 columns]

# %%
len(comprehensive_copy)
# Out:
# 28300

# %%
comprehensive_copy.head()
# Out:
#                   Player  Age    Position  Kit Number Nationality  In Squad  \
# 10119   thibaut courtois   31  Goalkeeper           1     Belgium         8
# 10120       andriy lunin   24  Goalkeeper          13     Ukraine        55
# 10121  kepa arrizabalaga   28  Goalkeeper          25       Spain        50
# 10122    lucas canizares   21  Goalkeeper           0       Spain         8
# 10123      mario de luis   21  Goalkeeper           0       Spain         3
#
#        Appearances  Goals  Assists  Yellow Cards  ...  Minutes Played  \
# 10119            5      0        0             0  ...           423.0
# 10120           31      0        0             2  ...          2850.0
# 10121           20      0        0             2  ...          1767.0
# 10122            0      0        0             0  ...             0.0
# 10123            0      0        0             0  ...             0.0
#
#               Club     Season         Team  Placement  League  \
# 10119  Real Madrid  2023/2024  real-madrid          1  laliga
# 10120  Real Madrid  2023/2024  real-madrid          1  laliga
# 10121  Real Madrid  2023/2024  real-madrid          1  laliga
# 10122  Real Madrid  2023/2024  real-madrid          1  laliga
# 10123  Real Madrid  2023/2024  real-madrid          1  laliga
#
#       Champions League Domestic Cup TOTY  TOTY_Nominee
# 10119                1            0    0             0
# 10120                1            0    0             0
# 10121                1            0    0             0
# 10122                1            0    0             0
# 10123                1            0    0             0
#
# [5 rows x 25 columns]

# %%
# Find players who are in comprehensive_2023_2024 but not in df_players
missing_players = comprehensive_copy[comprehensive_copy['Player'].apply(lambda x: x not in final_df['Player Name'].values)]

# Display the missing players along with their other attributes
missing_players
# Out:
#                     Player  Age        Position  Kit Number Nationality  \
# 1            victor valdes   26      Goalkeeper           1       Spain
# 6           martin caceres   21     Centre-Back           2     Uruguay
# 8             gerard pique   21     Centre-Back           3       Spain
# 9             rafa marquez   29     Centre-Back           4      Mexico
# 10            carles puyol   30     Centre-Back           5       Spain
# ...                    ...  ...             ...         ...         ...
# 57954        cheikh sabaly   24     Left Winger          14     Senegal
# 57969          isaak toure   20     Centre-Back          95      France
# 58002        aiyegun tosin   25  Centre-Forward          27       Benin
# 58019  cheick oumar konate   19      Right-Back          15        Mali
# 58039      elbasan rashani   30     Left Winger          18      Kosovo
#
#        In Squad  Appearances  Goals  Assists  Yellow Cards  ...  \
# 1            52           49      0        0             3  ...
# 6            51           23      0        0             3  ...
# 8            50           45      3        1             7  ...
# 9            41           37      3        3             7  ...
# 10           49           45      1        3             8  ...
# ...         ...          ...    ...      ...           ...  ...
# 57954        33           31      3        1             5  ...
# 57969        26           24      1        1             6  ...
# 58002        23           20      2        1             0  ...
# 58019        22           20      1        1             4  ...
# 58039        25           25      2        1             4  ...
#
#        Minutes Played              Club     Season              Team  \
# 1              4410.0      FC Barcelona  2008/2009      fc-barcelona
# 6              1523.0      FC Barcelona  2008/2009      fc-barcelona
# 8              3932.0      FC Barcelona  2008/2009      fc-barcelona
# 9              3020.0      FC Barcelona  2008/2009      fc-barcelona
# 10             3768.0      FC Barcelona  2008/2009      fc-barcelona
# ...               ...               ...        ...               ...
# 57954          1472.0           FC Metz  2023/2024           fc-metz
# 57969          2052.0        FC Lorient  2023/2024        fc-lorient
# 58002           974.0        FC Lorient  2023/2024        fc-lorient
# 58019          1139.0  Clermont Foot 63  2023/2024  clermont-foot-63
# 58039          1241.0  Clermont Foot 63  2023/2024  clermont-foot-63
#
#        Placement   League Champions League Domestic Cup TOTY  TOTY_Nominee
# 1              1   laliga                1            1    0             0
# 6              1   laliga                1            1    0             0
# 8              1   laliga                1            1    0             0
# 9              1   laliga                1            1    0             0
# 10             1   laliga                1            1    1             1
# ...          ...      ...              ...          ...  ...           ...
# 57954         16  ligue-1                0            0    0             0
# 57969         17  ligue-1                0            0    0             0
# 58002         17  ligue-1                0            0    0             0
# 58019         18  ligue-1                0            0    0             0
# 58039         18  ligue-1                0            0    0             0
#
# [19105 rows x 25 columns]

# %%
# Filter the DataFrame for the 2023/2024 season and players with more than 5 appearances
comprehensive_copy = comprehensive_df[(comprehensive_df['Appearances'] > 15) & (comprehensive_df['Season'] > '2017/2018')]

# Find players who are in comprehensive_2023_2024 but not in df_players
missing_players_full = comprehensive_copy[comprehensive_copy['Player'].apply(lambda x: x not in final_df['Player Name'].values)]

# Display the missing players along with their other attributes
missing_players_full
# Out:
#                     Player  Age        Position  Kit Number  \
# 6473                   NaN   23     Centre-Back          15
# 6521       juanfran torres   33      Right-Back          20
# 6550       daniel carvajal   26      Right-Back           2
# 6553       nacho fernandez   28     Centre-Back           6
# 6576          mariano diaz   24  Centre-Forward           7
# ...                    ...  ...             ...         ...
# 57998        mohamed bamba   21  Centre-Forward           9
# 58002        aiyegun tosin   25  Centre-Forward          27
# 58019  cheick oumar konate   19      Right-Back          15
# 58035     shamar nicholson   26  Centre-Forward          23
# 58039      elbasan rashani   30     Left Winger          18
#
#               Nationality  In Squad  Appearances  Goals  Assists  \
# 6473               France        57           45      2        1
# 6521                Spain        42           30      0        2
# 6550                Spain        40           37      1        6
# 6553                Spain        48           30      0        1
# 6576   Dominican Republic        24           19      4        0
# ...                   ...       ...          ...    ...      ...
# 57998       Cote d'Ivoire        16           16      8        3
# 58002               Benin        23           20      2        1
# 58019                Mali        22           20      1        1
# 58035             Jamaica        30           28      4        3
# 58039              Kosovo        25           25      2        1
#
#        Yellow Cards  ...  Minutes Played                Club     Season  \
# 6473             11  ...          3654.0        FC Barcelona  2018/2019
# 6521              8  ...          2336.0  Atlético de Madrid  2018/2019
# 6550             13  ...          3140.0         Real Madrid  2018/2019
# 6553              9  ...          2493.0         Real Madrid  2018/2019
# 6576              2  ...           602.0         Real Madrid  2018/2019
# ...             ...  ...             ...                 ...        ...
# 57998             3  ...          1149.0          FC Lorient  2023/2024
# 58002             0  ...           974.0          FC Lorient  2023/2024
# 58019             4  ...          1139.0    Clermont Foot 63  2023/2024
# 58035             2  ...          1657.0    Clermont Foot 63  2023/2024
# 58039             4  ...          1241.0    Clermont Foot 63  2023/2024
#
#                    Team  Placement   League Champions League Domestic Cup  \
# 6473       fc-barcelona          1   laliga                0            0
# 6521    atletico-madrid          2   laliga                0            0
# 6550        real-madrid          3   laliga                0            0
# 6553        real-madrid          3   laliga                0            0
# 6576        real-madrid          3   laliga                0            0
# ...                 ...        ...      ...              ...          ...
# 57998        fc-lorient         17  ligue-1                0            0
# 58002        fc-lorient         17  ligue-1                0            0
# 58019  clermont-foot-63         18  ligue-1                0            0
# 58035  clermont-foot-63         18  ligue-1                0            0
# 58039  clermont-foot-63         18  ligue-1                0            0
#
#       TOTY  TOTY_Nominee
# 6473     0             0
# 6521     0             0
# 6550     0             0
# 6553     0             0
# 6576     0             0
# ...    ...           ...
# 57998    0             0
# 58002    0             0
# 58019    0             0
# 58035    0             0
# 58039    0             0
#
# [1238 rows x 25 columns]

# %%
# Ensure the 'Player Name' column in df_players is of string type
final_df['Player Name'] = final_df['Player Name'].astype(str)

# Ensure the 'Player' column in missing_players is of string type
missing_players['Player'] = missing_players['Player'].astype(str)

# List to store matched results
matched_players = []

# Iterate over the missing players
for missing_name in missing_players['Player']:
    # Perform fuzzy matching
    best_match = process.extractOne(missing_name, final_df['Player Name'], scorer=fuzz.ratio)
    
    # If a match is found, unpack the result
    if best_match:
        match_name, match_score, match_index = best_match
        
        # Ensure the matched age is converted to an integer (in case it isn't already)
        matched_age = int(final_df.iloc[match_index]['Age'])
        missing_age = int(missing_players[missing_players['Player'] == missing_name]['Age'].values[0])
        
        # Calculate the age difference
        age_difference = abs(missing_age - matched_age)

        # Store the matched information including the age difference
        matched_players.append({
            'Missing Player': missing_name,
            'Matched Player': match_name,
            'Match Score': match_score,
            'Missing Age': missing_age,
            'Matched Age': matched_age,
            'Age Difference': age_difference,
            'Missing Nationality': missing_players[missing_players['Player'] == missing_name]['Nationality'].values[0],
            'Matched Nationality': final_df.iloc[match_index]['Nationality']
        })


# Convert the matched_players list to a DataFrame for easy viewing
matched_players_df = pd.DataFrame(matched_players)

# %%
matched_players_df.dtypes
# Out:
# Missing Player         object
# Matched Player         object
# Match Score             int64
# Missing Age             int64
# Matched Age             int64
# Age Difference          int64
# Missing Nationality    object
# Matched Nationality    object
# dtype: object

# %%
# Display the matched players
matched_players_df
# Out:
#            Missing Player          Matched Player  Match Score  Missing Age  \
# 0         daniel carvajal           dani carvajal           93           31
# 1         nacho fernandez          enzo fernandez           83           33
# 2                     nan                   natan           75           33
# 3                 savinho                   savio           83           19
# 4        viktor tsygankov        viktor tsyhankov           94           25
# 5           memphis depay                 memphis           70           29
# 6             dani vivian           daniel vivian           92           23
# 7                     nan                   natan           75           33
# 8                     nan                   natan           75           33
# 9           rodri sanchez          robert sanchez           81           23
# 10            dani parejo           daniel parejo           92           34
# 11              jose gaya          jose luis gaya           78           28
# 12                 pepelu                pep biel           71           24
# 13            javi guerra           javier guerra           92           20
# 14             fran perez         francisco perez           80           20
# 15            kike garcia              kike barja           76           33
# 16           abde rebbach     abderrahman rebbach           77           24
# 17       alejandro catena         alejandro balde           77           28
# 18     jose manuel arnaiz             jose arnaiz           76           28
# 19     jose angel carmona           jovane cabral           65           21
# 20          juan iglesias          borja iglesias           81           24
# 21                    nan                   natan           75           33
# 22        oscar rodriguez  oscar rodriguez arnaiz           81           25
# 23                    nan                   natan           75           33
# 24                    nan                   natan           75           33
# 25            jose copete                  copete           71           23
# 26             javi munoz            javier munoz           91           28
# 27                    nan                   natan           75           33
# 28            isi palazon   isaac palazon camacho           62           28
# 29          conan ledesma        jeremias ledesma           62           30
# 30            lucas pires             lucas digne           73           22
# 31           iza carcelen          isaac carcelen           85           30
# 32         robert navarro         roberto navarro           97           21
# 33                    nan                   natan           75           33
# 34              alex pozo             alex moreno           70           24
# 35                  chumi                  juanmi           55           24
# 36                    nan                   natan           75           33
# 37         adrian embarba            adri embarba           92           31
# 38                    nan                   natan           75           33
# 39                    nan                   natan           75           33
# 40  konstantinos tsimikas         kostas tsimikas           83           27
# 41          emerson royal                 emerson           70           24
# 42   pierre-emile hjbjerg          pierre hjbjerg           82           27
# 43          heung-min son           son heung-min           69           30
# 44       djordje petrovic            ore petrovic           86           23
# 45        mykhaylo mudryk         mykhailo mudryk           93           22
# 46        tino livramento    valentino livramento           86           20
# 47                    nan                   natan           75           33
# 48       lukasz fabianski         ukasz fabianski           97           38
# 49                    nan                   natan           75           33
#
#     Matched Age  Age Difference Missing Nationality Matched Nationality
# 0            31               0               Spain               Spain
# 1            22              11               Spain           Argentina
# 2            22              11               Spain              Brazil
# 3            19               0              Brazil              Brazil
# 4            25               0             Ukraine             Ukraine
# 5            29               0         Netherlands         Netherlands
# 6            24               1               Spain               Spain
# 7            22              11               Spain              Brazil
# 8            22              11               Spain              Brazil
# 9            25               2               Spain               Spain
# 10           34               0               Spain               Spain
# 11           28               0               Spain               Spain
# 12           26               2               Spain               Spain
# 13           20               0               Spain               Spain
# 14           20               0               Spain               Spain
# 15           26               7               Spain               Spain
# 16           24               0             Algeria             Algeria
# 17           19               9               Spain               Spain
# 18           28               0               Spain               Spain
# 19           25               4               Spain          Cape Verde
# 20           30               6               Spain               Spain
# 21           22              11               Spain              Brazil
# 22           25               0               Spain               Spain
# 23           22              11               Spain              Brazil
# 24           22              11               Spain              Brazil
# 25           23               0               Spain               Spain
# 26           28               0               Spain               Spain
# 27           22              11               Spain              Brazil
# 28           28               0               Spain               Spain
# 29           30               0           Argentina           Argentina
# 30           30               8              Brazil              France
# 31           30               0               Spain               Spain
# 32           21               0               Spain               Spain
# 33           22              11               Spain              Brazil
# 34           30               6               Spain               Spain
# 35           30               6               Spain               Spain
# 36           22              11               Spain              Brazil
# 37           31               0               Spain               Spain
# 38           22              11               Spain              Brazil
# 39           22              11               Spain              Brazil
# 40           27               0              Greece              Greece
# 41           24               0              Brazil              Brazil
# 42           27               0             Denmark             Denmark
# 43           31               1        Korea, South      Korea Republic
# 44           23               0              Serbia              Serbia
# 45           22               0             Ukraine             Ukraine
# 46           20               0             England             England
# 47           22              11               Spain              Brazil
# 48           38               0              Poland              Poland
# 49           22              11               Spain              Brazil

# %%
#Defensive stats
# Create a session
session = requests.Session()

# Define the retry strategy with a longer backoff time
retry = Retry(
    total=5,  # Total number of retries
    backoff_factor=5,  # Exponential backoff factor (5, 10, 20, 40 seconds)
    status_forcelist=[429, 500, 502, 503, 504],  # Retry on these HTTP status codes
    allowed_methods=["HEAD", "GET", "OPTIONS"]  # Retry for these methods
)

# Attach the HTTPAdapter with the retry strategy to the session
adapter = HTTPAdapter(max_retries=retry)
session.mount("http://", adapter)
session.mount("https://", adapter)

base_url = "https://fbref.com/en/comps/Big5/{}/defense/players/{}-Big-5-European-Leagues-Stats"
seasons = [
    "2017-2018", "2018-2019", "2019-2020", "2020-2021", "2021-2022", "2022-2023",
    "2023-2024"
]

all_players_data = []

for season in seasons:
    if season == "2023-2024":
        url = "https://fbref.com/en/comps/Big5/defense/players/Big-5-European-Leagues-Stats"
    else:
        url = base_url.format(season, season)
    
    # Make the request with retry logic
    try:
        response = session.get(url, headers={'User-Agent': 'Mozilla/5.0'})
        response.raise_for_status()  # Raise an error for bad status codes
        soup = BeautifulSoup(response.content, 'html.parser')
        rows = soup.select("#stats_defense > tbody > tr")
        
        for row in rows:
            player_name_element = row.select_one('td:nth-child(2)')
            tackles_made_element = row.select_one('td:nth-child(11)')
            tackle_percentage_element = row.select_one('td:nth-child(17)')
            interceptions_element = row.select_one('td:nth-child(22)')
            age_element = row.select_one('td:nth-child(7)')
            nation_link = row.select_one('td.left.poptip > a')
            
            if player_name_element and tackles_made_element and tackle_percentage_element and interceptions_element and age_element and nationality_element:
                player_name = player_name_element.text.strip()
                tackles_made = tackles_made_element.text.strip()
                tackle_percentage = tackle_percentage_element.text.strip()
                interceptions = interceptions_element.text.strip()
                         # Check if age_text is not empty and contains a dash
                age_text = age_element.text.strip()
                if age_text and '-' in age_text:
                    age = int(age_text.split('-')[0]) - 1
                elif age_text:  # Ensure age_text is not empty
                    age = int(age_text)
                else:
                    age = None  # or any default value if age is missing
                    
                 # Extract nationality and remove "Football" part
                nationality = ''
                if nation_link:
                    nationality = nation_link['href'].split('/')[-1].replace('-', ' ').title()
                    # Remove "Football" and everything after it
                    nationality = nationality.split(' Football')[0]
                
                all_players_data.append({
                    'Season': season,
                    'Player Name': player_name,
                    'Tackles Made': tackles_made,
                    'Tackle Percentage': tackle_percentage,
                    'Interceptions': interceptions,
                    'Age': age,
                    'Nationality': nationality
                })
        
        # Introduce a random delay between 5 and 10 seconds to avoid detection
        time.sleep(random.uniform(5, 10))

    except requests.exceptions.RequestException as e:
        print(f"Failed to fetch data for season {season}: {e}")

# %%
all_players_df = pd.DataFrame(all_players_data)
all_players_df
# Out:
#           Season          Player Name Tackles Made Tackle Percentage  \
# 0      2017-2018  Patrick van Aanholt           32              47.1
# 1      2017-2018       Rolando Aarons            4              66.7
# 2      2017-2018       Rolando Aarons            8              14.3
# 3      2017-2018        Ignazio Abate           17              54.5
# 4      2017-2018      Aymen Abdennour            3              57.1
# ...          ...                  ...          ...               ...
# 16768  2023-2024      Chrisantus Uche            0             100.0
# 16769  2023-2024          Mikel Vesga            1              50.0
# 16770  2023-2024        Daniel Vivian            0
# 16771  2023-2024       Iñaki Williams            0
# 16772  2023-2024        Nico Williams            0
#
#       Interceptions   Age  Nationality
# 0                47  26.0  Netherlands
# 1                 1  21.0      England
# 2                 2  21.0      England
# 3                 8  30.0        Italy
# 4                 4  27.0      Tunisia
# ...             ...   ...          ...
# 16768             0  20.0      Nigeria
# 16769             1  30.0        Spain
# 16770             0  24.0        Spain
# 16771             0  29.0        Ghana
# 16772             0  21.0        Spain
#
# [16773 rows x 7 columns]

# %%
#Passing stats
# Create a session
session = requests.Session()

# Define the retry strategy with a longer backoff time
retry = Retry(
    total=5,  # Total number of retries
    backoff_factor=5,  # Exponential backoff factor (5, 10, 20, 40 seconds)
    status_forcelist=[429, 500, 502, 503, 504],  # Retry on these HTTP status codes
    allowed_methods=["HEAD", "GET", "OPTIONS"]  # Retry for these methods
)

# Attach the HTTPAdapter with the retry strategy to the session
adapter = HTTPAdapter(max_retries=retry)
session.mount("http://", adapter)
session.mount("https://", adapter)

base_url = "https://fbref.com/en/comps/Big5/{}/passing/players/{}-Big-5-European-Leagues-Stats"
seasons = [
    "2017-2018", "2018-2019", "2019-2020", "2020-2021", "2021-2022", "2022-2023",
    "2023-2024"
]

all_passing_data = []

for season in seasons:
    if season == "2023-2024":
        url = "https://fbref.com/en/comps/Big5/passing/players/Big-5-European-Leagues-Stats"
    else:
        url = base_url.format(season, season)
    
    # Make the request with retry logic
    try:
        response = session.get(url, headers={'User-Agent': 'Mozilla/5.0'})
        response.raise_for_status()  # Raise an error for bad status codes
        soup = BeautifulSoup(response.content, 'html.parser')
        rows = soup.select("#stats_passing > tbody > tr")
        
        for row in rows:
            player_name_element = row.select_one('td:nth-child(2)')
            attempted_passes_element = row.select_one('td:nth-child(11)')
            completion_percentage_element = row.select_one('td:nth-child(12)')
            progressive_pass_distance_element = row.select_one('td:nth-child(14)')
            expected_assists_element = row.select_one('td:nth-child(25)')
            key_passes_element = row.select_one('td:nth-child(28)')
            age_element = row.select_one('td:nth-child(7)')
            nation_link = row.select_one('td.left.poptip > a')
            
            if player_name_element and attempted_passes_element and completion_percentage_element and progressive_pass_distance_element and expected_assists_element and key_passes_element and age_element and nationality_element:
                player_name = player_name_element.text.strip()
                attempted_passes = attempted_passes_element.text.strip()
                completion_percentage = completion_percentage_element.text.strip()
                progressive_pass_distance = progressive_pass_distance_element.text.strip()
                expected_assists = expected_assists_element.text.strip()
                key_passes = key_passes_element.text.strip()
                         # Get the raw age text
                         # Check if age_text is not empty and contains a dash
                age_text = age_element.text.strip()
                if age_text and '-' in age_text:
                    age = int(age_text.split('-')[0]) - 1
                elif age_text:  # Ensure age_text is not empty
                    age = int(age_text)
                else:
                    age = None  # or any default value if age is missing
                    
                 # Extract nationality and remove "Football" part
                nationality = ''
                if nation_link:
                    nationality = nation_link['href'].split('/')[-1].replace('-', ' ').title()
                    # Remove "Football" and everything after it
                    nationality = nationality.split(' Football')[0]
                
                all_passing_data.append({
                    'Season': season,
                    'Player Name': player_name,
                    'Attempted Passes': attempted_passes,
                    'Completion Percentage': completion_percentage,
                    'Progressive Pass Distance': progressive_pass_distance,
                    'Expected Assists': expected_assists,
                    'Key Passes': key_passes,
                    'Age': age,
                    'Nationality': nationality
                })
        
        # Introduce a random delay between 5 and 10 seconds to avoid detection
        time.sleep(random.uniform(5, 10))

    except requests.exceptions.RequestException as e:
        print(f"Failed to fetch data for season {season}: {e}")

# Convert the scraped data into a DataFrame
df_passing = pd.DataFrame(all_passing_data)

# %%
df_passing
# Out:
#           Season          Player Name Attempted Passes Completion Percentage  \
# 0      2017-2018  Patrick van Aanholt             1176                  75.2
# 1      2017-2018       Rolando Aarons               44                  65.9
# 2      2017-2018       Rolando Aarons              120                  72.5
# 3      2017-2018        Ignazio Abate              776                  80.5
# 4      2017-2018      Aymen Abdennour              333                  93.1
# ...          ...                  ...              ...                   ...
# 16768  2023-2024      Chrisantus Uche               11                  63.6
# 16769  2023-2024          Mikel Vesga               38                  71.1
# 16770  2023-2024        Daniel Vivian               19                  94.7
# 16771  2023-2024       Iñaki Williams               26                  61.5
# 16772  2023-2024        Nico Williams                8                  50.0
#
#       Progressive Pass Distance Expected Assists Key Passes   Age  Nationality
# 0                          6422              2.1         18  26.0  Netherlands
# 1                            77              0.0          0  21.0      England
# 2                           325              0.2          3  21.0      England
# 3                          4535              0.5         10  30.0        Italy
# 4                          1557              0.0          0  27.0      Tunisia
# ...                         ...              ...        ...   ...          ...
# 16768                         7              0.0          1  20.0      Nigeria
# 16769                       118              0.0          0  30.0        Spain
# 16770                       137              0.0          0  24.0        Spain
# 16771                        42              0.0          0  29.0        Ghana
# 16772                         2              0.0          0  21.0        Spain
#
# [16773 rows x 9 columns]

# %%
#Goalkeeping stats
# Create a session
session = requests.Session()

# Define the retry strategy with a longer backoff time
retry = Retry(
    total=5,  # Total number of retries
    backoff_factor=5,  # Exponential backoff factor (5, 10, 20, 40 seconds)
    status_forcelist=[429, 500, 502, 503, 504],  # Retry on these HTTP status codes
    allowed_methods=["HEAD", "GET", "OPTIONS"]  # Retry for these methods
)

# Attach the HTTPAdapter with the retry strategy to the session
adapter = HTTPAdapter(max_retries=retry)
session.mount("http://", adapter)
session.mount("https://", adapter)

base_url = "https://fbref.com/en/comps/Big5/{}/keepers/players/{}-Big-5-European-Leagues-Stats"
seasons = [
    "2017-2018", "2018-2019", "2019-2020", "2020-2021", "2021-2022", "2022-2023",
    "2023-2024"
]

all_goalkeeper_data = []

for season in seasons:
    if season == "2023-2024":
        url = "https://fbref.com/en/comps/Big5/keepers/players/Big-5-European-Leagues-Stats"
    else:
        url = base_url.format(season, season)
    
    # Make the request with retry logic
    try:
        response = session.get(url, headers={'User-Agent': 'Mozilla/5.0'})
        response.raise_for_status()  # Raise an error for bad status codes
        soup = BeautifulSoup(response.content, 'html.parser')
        rows = soup.select("#stats_keeper > tbody > tr")
        
        for row in rows:
            player_name_element = row.select_one('td:nth-child(2)')
            position_element = row.select_one('td:nth-child(4)')
            goals_against_element = row.select_one('td:nth-child(13)')
            shots_on_target_against_element = row.select_one('td:nth-child(15)')
            saves_element = row.select_one('td:nth-child(16)')
            save_percentage_element = row.select_one('td:nth-child(17)')
            clean_sheets_element = row.select_one('td:nth-child(21)')
            clean_sheet_percentage_element = row.select_one('td:nth-child(22)')
            age_element = row.select_one('td:nth-child(7)')
            nation_link = row.select_one('td.left.poptip > a')
            
            if player_name_element and position_element and goals_against_element and shots_on_target_against_element and saves_element and save_percentage_element and clean_sheets_element and clean_sheet_percentage_element and age_element and nationality_element:
                player_name = player_name_element.text.strip()
                position = position_element.text.strip()
                goals_against = goals_against_element.text.strip() or '0'
                shots_on_target_against = shots_on_target_against_element.text.strip() or '0'
                saves = saves_element.text.strip() or '0'
                save_percentage = save_percentage_element.text.strip() or '0'
                clean_sheets = clean_sheets_element.text.strip() or '0'
                clean_sheet_percentage = clean_sheet_percentage_element.text.strip() or '0'
                         # Get the raw age text
                 # Process age to handle dashes
                                  # Check if age_text is not empty and contains a dash
                age_text = age_element.text.strip()
                if age_text and '-' in age_text:
                    age = int(age_text.split('-')[0]) - 1
                elif age_text:  # Ensure age_text is not empty
                    age = int(age_text)
                else:
                    age = None  # or any default value if age is missing
                    
                 # Extract nationality and remove "Football" part
                nationality = ''
                if nation_link:
                    nationality = nation_link['href'].split('/')[-1].replace('-', ' ').title()
                    # Remove "Football" and everything after it
                    nationality = nationality.split(' Football')[0]
                
                all_goalkeeper_data.append({
                    'Season': season,
                    'Player Name': player_name,
                    'Position': position,
                    'Goals Against': goals_against,
                    'Shots on Target Against': shots_on_target_against,
                    'Saves': saves,
                    'Save Percentage': save_percentage,
                    'Clean Sheets': clean_sheets,
                    'Clean Sheet Percentage': clean_sheet_percentage,
                    'Age': age,
                    'Nationality': nationality
                })
        
        # Introduce a random delay between 5 and 10 seconds to avoid detection
        time.sleep(random.uniform(5, 10))

    except requests.exceptions.RequestException as e:
        print(f"Failed to fetch data for season {season}: {e}")

# Convert the scraped data into a DataFrame
df_goalkeepers = pd.DataFrame(all_goalkeeper_data)

# %%
df_goalkeepers
# Out:
#          Season      Player Name Position Goals Against  \
# 0     2017-2018     Antonio Adán       GK            53
# 1     2017-2018       René Adler       GK            18
# 2     2017-2018           Adrián       GK            29
# 3     2017-2018          Alisson       GK            28
# 4     2017-2018   Sergio Álvarez       GK            29
# ...         ...              ...      ...           ...
# 1246  2022-2023      Petar Zovko       GK             2
# 1247  2023-2024  Paulo Gazzaniga       GK             1
# 1248  2023-2024     Alex Padilla       GK             1
# 1249  2023-2024        Rui Silva       GK             1
# 1250  2023-2024      David Soria       GK             1
#
#      Shots on Target Against Saves Save Percentage Clean Sheets  \
# 0                        132    82            62.1            9
# 1                         53    35            67.9            4
# 2                         96    68            70.8            6
# 3                        135   105            81.5           17
# 4                         75    47            62.7            3
# ...                      ...   ...             ...          ...
# 1246                       3     1            33.3            0
# 1247                       4     3            75.0            0
# 1248                       2     1            50.0            0
# 1249                       2     1            50.0            0
# 1250                       4     3            75.0            0
#
#      Clean Sheet Percentage  Age             Nationality
# 0                      30.0   30                   Spain
# 1                      28.6   32                 Germany
# 2                      31.6   30                   Spain
# 3                      45.9   24                  Brazil
# 4                      18.8   30                   Spain
# ...                     ...  ...                     ...
# 1246                      0   20  Bosnia And Herzegovina
# 1247                    0.0   31               Argentina
# 1248                    0.0   19                   Spain
# 1249                    0.0   29                Portugal
# 1250                    0.0   30                   Spain
#
# [1251 rows x 11 columns]

# %%
# Step 1: Merge all_players_df with df_passing
# Step 1: Merge all_players_df with df_passing on 'Name', 'Season', and 'Age'
combined_df = pd.merge(all_players_df, df_passing, on=['Player Name', 'Season', 'Age'], how='outer')

#combined_df

combined_df_check = combined_df[(combined_df['Season'] > '2022/2023')]
combined_df_check

# Step 2: Merge the result with df_goalkeepers on 'Name', 'Season', and 'Age'
final_df = pd.merge(combined_df, df_goalkeepers, on=['Player Name', 'Season', 'Age'], how='outer')
final_df
# Out:
#           Season      Player Name Tackles Made Tackle Percentage  \
# 0      2019-2020   Aaron Connolly            6              30.0
# 1      2020-2021   Aaron Connolly            3               0.0
# 2      2021-2022   Aaron Connolly            0               0.0
# 3      2017-2018  Aaron Cresswell           21              63.3
# 4      2018-2019  Aaron Cresswell           16              52.0
# ...          ...              ...          ...               ...
# 18366  2018-2019      Ștefan Radu           27              65.8
# 18367  2019-2020      Ștefan Radu           25              65.1
# 18368  2020-2021      Ștefan Radu           24              62.5
# 18369  2021-2022      Ștefan Radu            6              55.6
# 18370  2022-2023      Ștefan Radu            0
#
#       Interceptions   Age        Nationality_x Attempted Passes  \
# 0                 0  19.0  Republic Of Ireland              155
# 1                 0  20.0  Republic Of Ireland               94
# 2                 0  21.0  Republic Of Ireland               19
# 3                44  27.0              England             1723
# 4                23  28.0              England             1082
# ...             ...   ...                  ...              ...
# 18366            42  31.0              Romania             1329
# 18367            34  32.0              Romania             1378
# 18368            45  33.0              Romania             1635
# 18369             5  34.0              Romania              330
# 18370             0  35.0              Romania                7
#
#       Completion Percentage Progressive Pass Distance  ... Key Passes  \
# 0                      72.9                       183  ...          6
# 1                      76.6                       176  ...          6
# 2                      73.7                        16  ...          1
# 3                      69.9                      9345  ...         34
# 4                      78.4                      5043  ...         17
# ...                     ...                       ...  ...        ...
# 18366                  84.0                      7405  ...          9
# 18367                  86.2                      7370  ...         13
# 18368                  82.9                      9253  ...         19
# 18369                  81.2                      1809  ...          0
# 18370                  85.7                        21  ...          0
#
#              Nationality_y Position Goals Against Shots on Target Against  \
# 0      Republic Of Ireland      NaN           NaN                     NaN
# 1      Republic Of Ireland      NaN           NaN                     NaN
# 2      Republic Of Ireland      NaN           NaN                     NaN
# 3                  England      NaN           NaN                     NaN
# 4                  England      NaN           NaN                     NaN
# ...                    ...      ...           ...                     ...
# 18366              Romania      NaN           NaN                     NaN
# 18367              Romania      NaN           NaN                     NaN
# 18368              Romania      NaN           NaN                     NaN
# 18369              Romania      NaN           NaN                     NaN
# 18370              Romania      NaN           NaN                     NaN
#
#       Saves Save Percentage Clean Sheets Clean Sheet Percentage Nationality
# 0       NaN             NaN          NaN                    NaN         NaN
# 1       NaN             NaN          NaN                    NaN         NaN
# 2       NaN             NaN          NaN                    NaN         NaN
# 3       NaN             NaN          NaN                    NaN         NaN
# 4       NaN             NaN          NaN                    NaN         NaN
# ...     ...             ...          ...                    ...         ...
# 18366   NaN             NaN          NaN                    NaN         NaN
# 18367   NaN             NaN          NaN                    NaN         NaN
# 18368   NaN             NaN          NaN                    NaN         NaN
# 18369   NaN             NaN          NaN                    NaN         NaN
# 18370   NaN             NaN          NaN                    NaN         NaN
#
# [18371 rows x 21 columns]

# %%
# Apply the normalization function to the 'Player Name' column
final_df['Player Name'] = final_df['Player Name'].apply(normalize_string)

# Display the DataFrame to verify the changes
print(final_df.head())
# Out:
#       Season      Player Name Tackles Made Tackle Percentage Interceptions  \
# 0  2019-2020   aaron connolly            6              30.0             0
# 1  2020-2021   aaron connolly            3               0.0             0
# 2  2021-2022   aaron connolly            0               0.0             0
# 3  2017-2018  aaron cresswell           21              63.3            44
# 4  2018-2019  aaron cresswell           16              52.0            23
#
#     Age        Nationality_x Attempted Passes Completion Percentage  \
# 0  19.0  Republic Of Ireland              155                  72.9
# 1  20.0  Republic Of Ireland               94                  76.6
# 2  21.0  Republic Of Ireland               19                  73.7
# 3  27.0              England             1723                  69.9
# 4  28.0              England             1082                  78.4
#
#   Progressive Pass Distance  ... Key Passes        Nationality_y Position  \
# 0                       183  ...          6  Republic Of Ireland      NaN
# 1                       176  ...          6  Republic Of Ireland      NaN
# 2                        16  ...          1  Republic Of Ireland      NaN
# 3                      9345  ...         34              England      NaN
# 4                      5043  ...         17              England      NaN
#
#   Goals Against Shots on Target Against Saves Save Percentage Clean Sheets  \
# 0           NaN                     NaN   NaN             NaN          NaN
# 1           NaN                     NaN   NaN             NaN          NaN
# 2           NaN                     NaN   NaN             NaN          NaN
# 3           NaN                     NaN   NaN             NaN          NaN
# 4           NaN                     NaN   NaN             NaN          NaN
#
#   Clean Sheet Percentage Nationality
# 0                    NaN         NaN
# 1                    NaN         NaN
# 2                    NaN         NaN
# 3                    NaN         NaN
# 4                    NaN         NaN
#
# [5 rows x 21 columns]

# %%
# Ensure the 'Player Name' column in df_players is of string type
final_df['Player Name'] = final_df['Player Name'].astype(str)

# Ensure the 'Player' column in missing_players is of string type
missing_players['Player'] = missing_players['Player'].astype(str)

# List to store matched results
matched_players = []

# Iterate over the missing players
for missing_name in missing_players['Player']:
    # Perform fuzzy matching
    best_match = process.extractOne(missing_name, final_df['Player Name'], scorer=fuzz.ratio)
    
    # If a match is found, unpack the result
    if best_match:
        match_name, match_score, match_index = best_match
        
        # Ensure the matched age is converted to an integer (in case it isn't already)
        matched_age = int(final_df.iloc[match_index]['Age'])
        missing_age = int(missing_players[missing_players['Player'] == missing_name]['Age'].values[0])
        
        # Calculate the age difference
        age_difference = abs(missing_age - matched_age)

        # Store the matched information including the age difference
        matched_players.append({
            'Missing Player': missing_name,
            'Matched Player': match_name,
            'Match Score': match_score,
            'Missing Age': missing_age,
            'Matched Age': matched_age,
            'Age Difference': age_difference,
            'Missing Nationality': missing_players[missing_players['Player'] == missing_name]['Nationality'].values[0],
            'Matched Nationality': final_df.iloc[match_index]['Nationality']
        })


# Convert the matched_players list to a DataFrame for easy viewing
matched_players_df = pd.DataFrame(matched_players)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[67], line 13
#      10 # Iterate over the missing players
#      11 for missing_name in missing_players['Player']:
#      12     # Perform fuzzy matching
# ---> 13     best_match = process.extractOne(missing_name, final_df['Player Name'], scorer=fuzz.ratio)
#      15     # If a match is found, unpack the result
#      16     if best_match:
#
# File ~\anaconda3\Lib\site-packages\fuzzywuzzy\process.py:220, in extractOne(query, choices, processor, scorer, score_cutoff)
#     218 best_list = extractWithoutOrder(query, choices, processor, scorer, score_cutoff)
#     219 try:
# --> 220     return max(best_list, key=lambda i: i[1])
#     221 except ValueError:
#     222     return None
#
# File ~\anaconda3\Lib\site-packages\fuzzywuzzy\process.py:110, in extractWithoutOrder(query, choices, processor, scorer, score_cutoff)
#     108 for key, choice in choices.items():
#     109     processed = pre_processor(processor(choice))
# --> 110     score = scorer(processed_query, processed)
#     111     if score >= score_cutoff:
#     112         yield (choice, score, key)
#
# File ~\anaconda3\Lib\site-packages\fuzzywuzzy\utils.py:38, in check_for_none.<locals>.decorator(*args, **kwargs)
#      36 if args[0] is None or args[1] is None:
#      37     return 0
# ---> 38 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\fuzzywuzzy\utils.py:29, in check_for_equivalence.<locals>.decorator(*args, **kwargs)
#      27 if args[0] == args[1]:
#      28     return 100
# ---> 29 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\fuzzywuzzy\utils.py:47, in check_empty_string.<locals>.decorator(*args, **kwargs)
#      45 if len(args[0]) == 0 or len(args[1]) == 0:
#      46     return 0
# ---> 47 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\fuzzywuzzy\fuzz.py:28, in ratio(s1, s2)
#      25 s1, s2 = utils.make_type_consistent(s1, s2)
#      27 m = SequenceMatcher(None, s1, s2)
# ---> 28 return utils.intr(100 * m.ratio())
#
# File ~\anaconda3\Lib\difflib.py:619, in SequenceMatcher.ratio(self)
#     597 def ratio(self):
#     598     """Return a measure of the sequences' similarity (float in [0,1]).
#     599
#     600     Where T is the total number of elements in both sequences, and
#    (...)
#     616     1.0
#     617     """
# --> 619     matches = sum(triple[-1] for triple in self.get_matching_blocks())
#     620     return _calculate_ratio(matches, len(self.a) + len(self.b))
#
# File ~\anaconda3\Lib\difflib.py:453, in SequenceMatcher.get_matching_blocks(self)
#     451 matching_blocks = []
#     452 while queue:
# --> 453     alo, ahi, blo, bhi = queue.pop()
#     454     i, j, k = x = self.find_longest_match(alo, ahi, blo, bhi)
#     455     # a[alo:i] vs b[blo:j] unknown
#     456     # a[i:i+k] same as b[j:j+k]
#     457     # a[i+k:ahi] vs b[j+k:bhi] unknown
#
# KeyboardInterrupt:

# %%
matched_players_df
